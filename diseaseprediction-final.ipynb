# %%
from tkinter import *                        #import everything(*) from tkinter library
from tkinter import messagebox               #import messagebox from tkinter library(to display instructions/errors)
import numpy as np                           #import numpy library(to work with numbers)(arrays)
import pandas as pd                          #import pandas library(to work with tabular data)(multi-dimensional arrays)


#List of the symptoms is listed here in list l1.

l1=['back_pain','constipation','abdominal_pain','diarrhoea','mild_fever','yellow_urine',
'yellowing_of_eyes','acute_liver_failure','fluid_overload','swelling_of_stomach',
'swelled_lymph_nodes','malaise','blurred_and_distorted_vision','phlegm','throat_irritation',
'redness_of_eyes','sinus_pressure','runny_nose','congestion','chest_pain','weakness_in_limbs',
'fast_heart_rate','pain_during_bowel_movements','pain_in_anal_region','bloody_stool',
'irritation_in_anus','neck_pain','dizziness','cramps','bruising','obesity','swollen_legs',
'swollen_blood_vessels','puffy_face_and_eyes','enlarged_thyroid','brittle_nails',
'swollen_extremeties','excessive_hunger','extra_marital_contacts','drying_and_tingling_lips',
'slurred_speech','knee_pain','hip_joint_pain','muscle_weakness','stiff_neck','swelling_joints',
'movement_stiffness','spinning_movements','loss_of_balance','unsteadiness',
'weakness_of_one_body_side','loss_of_smell','bladder_discomfort','foul_smell_of urine',
'continuous_feel_of_urine','passage_of_gases','internal_itching','toxic_look_(typhos)',
'depression','irritability','muscle_pain','altered_sensorium','red_spots_over_body','belly_pain',
'abnormal_menstruation','dischromic _patches','watering_from_eyes','increased_appetite','polyuria','family_history','mucoid_sputum',
'rusty_sputum','lack_of_concentration','visual_disturbances','receiving_blood_transfusion',
'receiving_unsterile_injections','coma','stomach_bleeding','distention_of_abdomen',
'history_of_alcohol_consumption','fluid_overload','blood_in_sputum','prominent_veins_on_calf',
'palpitations','painful_walking','pus_filled_pimples','blackheads','scurring','skin_peeling',
'silver_like_dusting','small_dents_in_nails','inflammatory_nails','blister','red_sore_around_nose',
'yellow_crust_ooze']

#List of Diseases is listed in list disease.

disease=['Fungal infection','Allergy','GERD','Chronic cholestasis','Drug Reaction',
'Peptic ulcer diseae','AIDS','Diabetes','Gastroenteritis','Bronchial Asthma','Hypertension',
' Migraine','Cervical spondylosis',
'Paralysis (brain hemorrhage)','Jaundice','Malaria','Chicken pox','Dengue','Typhoid','hepatitis A',
'Hepatitis B','Hepatitis C','Hepatitis D','Hepatitis E','Alcoholic hepatitis','Tuberculosis',
'Common Cold','Pneumonia','Dimorphic hemmorhoids(piles)',
'Heartattack','Varicoseveins','Hypothyroidism','Hyperthyroidism','Hypoglycemia','Osteoarthristis',
'Arthritis','(vertigo) Paroymsal  Positional Vertigo','Acne','Urinary tract infection','Psoriasis',
'Impetigo']

l2=[]                 #creating empty list to store symptoms to display as per the symptoms given by user

for i in range(0,len(l1)):
    l2.append(0)

df=pd.read_csv(r"C:\Users\DHRUVIN VADALIA\Desktop\Mini Project\TrainingDataset.csv") #reading file from source location in order to work with datasets(imported using pandas as we have to work with tabular data)

#Replace the values in the imported file by pandas by the inbuilt function replace in pandas.

df.replace({'prognosis':{'Fungal infection':0,'Allergy':1,'GERD':2,'Chronic cholestasis':3,'Drug Reaction':4,
'Peptic ulcer diseae':5,'AIDS':6,'Diabetes ':7,'Gastroenteritis':8,'Bronchial Asthma':9,'Hypertension ':10,
'Migraine':11,'Cervical spondylosis':12,
'Paralysis (brain hemorrhage)':13,'Jaundice':14,'Malaria':15,'Chicken pox':16,'Dengue':17,'Typhoid':18,'hepatitis A':19,
'Hepatitis B':20,'Hepatitis C':21,'Hepatitis D':22,'Hepatitis E':23,'Alcoholic hepatitis':24,'Tuberculosis':25,
'Common Cold':26,'Pneumonia':27,'Dimorphic hemmorhoids(piles)':28,'Heart attack':29,'Varicose veins':30,'Hypothyroidism':31,
'Hyperthyroidism':32,'Hypoglycemia':33,'Osteoarthristis':34,'Arthritis':35,
'(vertigo) Paroymsal  Positional Vertigo':36,'Acne':37,'Urinary tract infection':38,'Psoriasis':39,
'Impetigo':40}},inplace=True) #Here, inplace=True, because the data in dataset is modified without assigning it to a new variable

#check the df 
#print(df.head())

X= df[l1]                     #creating array containing all the symptoms

#print(X)

y = df[["prognosis"]]
np.ravel(y)                   #converted into contigious flattened array(prognosis column)


#print(y)

#Read a csv named TestingDataset.csv

tr=pd.read_csv(r"C:\Users\DHRUVIN VADALIA\Desktop\Mini Project\TestingDataset.csv")  #reading file from source location in order to work with datasets(imported using pandas as we have to work with tabular data)

#Use replace method in pandas.

tr.replace({'prognosis':{'Fungal infection':0,'Allergy':1,'GERD':2,'Chronic cholestasis':3,'Drug Reaction':4,
'Peptic ulcer diseae':5,'AIDS':6,'Diabetes ':7,'Gastroenteritis':8,'Bronchial Asthma':9,'Hypertension ':10,
'Migraine':11,'Cervical spondylosis':12,
'Paralysis (brain hemorrhage)':13,'Jaundice':14,'Malaria':15,'Chicken pox':16,'Dengue':17,'Typhoid':18,'hepatitis A':19,
'Hepatitis B':20,'Hepatitis C':21,'Hepatitis D':22,'Hepatitis E':23,'Alcoholic hepatitis':24,'Tuberculosis':25,
'Common Cold':26,'Pneumonia':27,'Dimorphic hemmorhoids(piles)':28,'Heart attack':29,'Varicose veins':30,'Hypothyroidism':31,
'Hyperthyroidism':32,'Hypoglycemia':33,'Osteoarthristis':34,'Arthritis':35,
'(vertigo) Paroymsal  Positional Vertigo':36,'Acne':37,'Urinary tract infection':38,'Psoriasis':39,
'Impetigo':40}},inplace=True)  #Here, inplace=True, because the data in dataset is modified without assigning it to a new variable

X_test= tr[l1]
y_test = tr[["prognosis"]]

#print(y_test)

np.ravel(y_test)

#Creating root
root = Tk()   #app window is created
root.configure(background='green')  #background colour of window is assigned
root.title('Project by Haroon Shaikh , Dhruvin Vadalia & Govind Pandey')  #window title is assigned

pred1=StringVar()   #the input given by user would be string(i.e. the symptoms) so we have used stringvar
def DecisionTree(): #starting of decision tree algorithm(function)
    if((Symptom1.get()=="Select Symptom1 Here") or (Symptom2.get()=="Select Symptom2 Here")):  #checking if atleast 2 symptoms are given by user or not
        pred1.set(" ")  #if nothing is selected by user then set the predicted disease as null(nothing would be displayed in front of dicision tree prediction)
        sym=messagebox.askokcancel("System","Kindly fill atleast two symptoms")  #if atleast 2 symptoms are not given by user then display this error msg
        if sym:
            root.mainloop()  
    else:  #if atleast 2 symptoms are given by user then continue with the processing of the decisiontree algorithm
        from sklearn import tree  #importing tree module from sklearn library as we are working on decision tree algorithm

        model1 = tree.DecisionTreeClassifier()  #using decisiontreeclassifier function for classification and to measure the quality of split
        model1 = model1.fit(X,y)       #The fit() method takes the training data as arguments, which can be one array in the case of unsupervised learning, or two arrays in the case of supervised learning. Note that the model is fitted using X and y , but the object holds no reference to X and y .(training)

        from sklearn.metrics import accuracy_score   #importing function accuracy_score from sklearn.metrics module
        y_pred=model1.predict(X_test)  #passing X_test(i.e. symptoms) as argument in predict function in order to predict the y value(i.e. disease)
        print('DecisionTree Accuracy:' ,accuracy_score(y_test, y_pred))   #print the accuracy of the predicted result
        
        
        psymptoms = [Symptom1.get(),Symptom2.get(),Symptom3.get(),Symptom4.get(),Symptom5.get()]  #taking input of all the symptoms through tkinter gui

        for k in range(0,len(l1)):   #creating for loop inside a for loop to match the symptoms given by user with the symptoms in dataset
            for z in psymptoms:
                if(z==l1[k]):
                    l2[k]=1

        inputtest = [l2]   #list l2 is given as input to the inputtest variable and it is passed as parameter in predict function to find the predicted disease
        predict = model1.predict(inputtest)
        predicted=predict[0]

        h='no'   #by default value of h is set equal to 'no'
        for a in range(0,len(disease)): #Here, we again use a for loop inside a for loop to match the name of disease with the coreesponding disease number
            if(predicted == a):
                h='yes'
                break


        if (h=='yes'):   #if disease is predicted by matching the number then set the predicted disease box in front of dicisiontree algorithm to blank and then freshly fill that box with the name of the predicted diasease
            pred1.set(" ")
            pred1.set(disease[a])
        else:
            pred1.set(" ")
            pred1.set("Not Found") #if disease is not predicted then the corresponding box would be filled with "Not Found"

#all the things which we performed for dicision tree algorithm would be carried out for random forest & naive bayes algorithm
    
pred2=StringVar()   #the input given by user would be string(i.e. the symptoms) so we have used stringvar
def randomforest(): #starting of decision tree algorithm(function)
    if((Symptom1.get()=="Select Symptom1 Here") or (Symptom2.get()=="Select Symptom2 Here")):  #checking if atleast 2 symptoms are given by user or not
        pred1.set(" ")  #if nothing is selected by user then set the predicted disease as null(nothing would be displayed in front of dicision tree prediction)
        sym=messagebox.askokcancel("System","Kindly fill atleast two symptoms")  #if atleast 2 symptoms are not given by user then display this error msg
        if sym:
            root.mainloop()  
    else:   #if atleast 2 symptoms are given by user then continue with the processing of the randomforest algorithm
  
        from sklearn.ensemble import RandomForestClassifier  #importing randomforestclassifier module from sklearn library as we are working on random forest algorithm
        model2 = RandomForestClassifier()   #using randomforestclassfier function for classification of symptoms to predict disease
        model2 = model2.fit(X,np.ravel(y))  #The fit() method takes the training data as arguments, which can be one array in the case of unsupervised learning, or two arrays in the case of supervised learning. Note that the model is fitted using X and y , but the object holds no reference to X and y .(training)

    # calculating accuracy 
        from sklearn.metrics import accuracy_score  #importing function accuracy_score from sklearn.metrics module
        y_pred=model2.predict(X_test)  #passing X_test(i.e. symptoms) as argument in predict function in order to predict the y value(i.e. disease)
        print('Randomforest Accuracy:' ,accuracy_score(y_test, y_pred))  #print the accuracy of the predicted result
       
    
        psymptoms = [Symptom1.get(),Symptom2.get(),Symptom3.get(),Symptom4.get(),Symptom5.get()]  #taking input of all the symptoms through tkinter gui

        for k in range(0,len(l1)):   #matching of symptoms given by user with those in database and storing matched symptoms in list l2 by making corresponding symptom equal to 1
            for z in psymptoms:
                if(z==l1[k]):
                    l2[k]=1

        inputtest = [l2]   #set inputtest equal to l2(which contains all the symptoms selected by user)
        predict = model2.predict(inputtest)  #use predict function on it to predict the disease
        predicted=predict[0]   #set the predicted variable equal to the predicted disease

        h='no'  #set value of h = 'no' by default
        for a in range(0,len(disease)):  #Here, we again use a for loop inside a for loop to match the name of disease with the coreesponding disease number
            if(predicted == a):  #if successfully matched then set h = 'yes'
                h='yes'
                break

        if (h=='yes'):   #when yes then clear the corresponding box in front of randomforest and fill that box with the predicted disease
            pred2.set(" ")
            pred2.set(disease[a])
        else:
            pred2.set(" ")
            pred2.set("Not Found")  #else fill that box with the "Not Found" message
            
pred3=StringVar()  #symptoms in string format so stringvar function is used
def NaiveBayes():  #starting of naive bayes algorithm
    if((Symptom1.get()=="Select Symptom1 Here") or (Symptom2.get()=="Select Symptom2 Here")):  #check if atleast 2 symptoms are given or not
        pred1.set(" ")   #if not given then fill null in the textbox in front of naive bayes
        sym=messagebox.askokcancel("System","Kindly fill atleast two symptoms")  #and dispaly this msgbox
        if sym:
            root.mainloop()
    else:
    #if atleast 2 symptoms are given by user then continue with the processing of the randomforest algorithm    
        
        from sklearn.naive_bayes import GaussianNB  #importing randomforestclassifier module from sklearn library as we are working on random forest algorithm
        model3 = GaussianNB()   #using gaussiannb function for prediction(classification)
        model3=model3.fit(X,np.ravel(y)) #fitting the values of x and y(i.e. symptoms and disease) for traing purpose

        from sklearn.metrics import accuracy_score  #importing function accuracy_score from sklearn.metrics module
        y_pred=model3.predict(X_test)   #passing X_test(i.e. symptoms) as argument in predict function in order to predict the y value(i.e. disease)
        print('NaiveBayes Accuracy:' ,accuracy_score(y_test, y_pred))  #displaying the accuracy of naive bayes algorithm
    

        psymptoms = [Symptom1.get(),Symptom2.get(),Symptom3.get(),Symptom4.get(),Symptom5.get()]  #taking 5 inputs of symptoms from user
        for k in range(0,len(l1)):  #matching the symptoms given by user with those present in the database
            for z in psymptoms:
                if(z==l1[k]):  #if successfully matched then set the list l2 with 1 in front of that particular symptom
                    l2[k]=1

        inputtest = [l2]  #set list l2 equal to inputtest
        predict = model3.predict(inputtest)  #use predict function on the inputtest(i.e. all the symptoms given by user)
        predicted=predict[0]   #set predicted equal to the predicted disease number

        h='no'  # by default h is equal to no
        for a in range(0,len(disease)):  #use for loop inside a for loop to match the predicted disease number with the diasease number in the dataset
            if(predicted == a):  #if successfully matched then set the value of h equal to yes
                h='yes'
                break

        if (h=='yes'):  #if h is yes then clear the corresponding box in front of naive bayes and fill it with the name of predicted disease
            pred3.set(" ")
            pred3.set(disease[a])
        else:
            pred3.set(" ")
            pred3.set("Not Found")  #else fill that box with "Not Found"

        
  
    
# GUI 
        


Symptom1 = StringVar()  #here stringvar is used as each and every symptoms from 1 to 5 would be of string datatype
Symptom1.set("Select Symptom1 Here")

Symptom2 = StringVar()
Symptom2.set("Select Symptom2 Here")

Symptom3 = StringVar()
Symptom3.set("Select Symptom3 Here")

Symptom4 = StringVar()
Symptom4.set("Select Symptom4 Here")

Symptom5 = StringVar()
Symptom5.set("Select Symptom5 Here")

Name = StringVar()  #Name of the user would also be of string datatype so again StringVar() is used

#function to Reset the given inputs to initial position
prev_win=None
def Reset():  #reset function is used so that the next user can predict his/her disease
    global prev_win

    Symptom1.set("Select Symptom1 Here")  #all symptoms values again set to previous value
    Symptom2.set("Select Symptom2 Here")
    Symptom3.set("Select Symptom3 Here")
    Symptom4.set("Select Symptom4 Here")
    Symptom5.set("Select Symptom5 Here")
    
    NameEn.delete(first=0,last=100)
    
    pred1.set(" ")  #all predicted result would also be reset
    pred2.set(" ")
    pred3.set(" ")

    l2.clear()                        #if clear button is clicked then the list l2 which already contained the previous symptoms gets cleared for the new ones
    for i in range(0,len(l1)):
        l2.append(0)
    try:
        prev_win.destroy()
        prev_win=None
    except AttributeError:
        pass

w2 = Label(root, justify=CENTER, text="Human Disease Prediction Based On Symptoms ", fg="Red", bg="Pink")  #label displaying text with appropriate attributes such as size, font, alignment, colour(both background and foreground)
w2.config(font=("Times",30,"bold italic"))
w2.grid(row=2, column=0, columnspan=2, padx=100)

NameLb = Label(root, text="Name of the Patient", fg="Red", bg="Sky Blue")
NameLb.config(font=("Times",15,"bold italic"))
NameLb.grid(row=6, column=0, pady=15,padx=20, sticky=W)

S1Lb = Label(root, text="Symptom 1", fg="Blue", bg="Pink")
S1Lb.config(font=("Times",15,"bold italic"))
S1Lb.grid(row=7, column=0, pady=10,padx=20, sticky=W)

S2Lb = Label(root, text="Symptom 2", fg="White", bg="Purple")
S2Lb.config(font=("Times",15,"bold italic"))
S2Lb.grid(row=8, column=0, pady=10,padx=20, sticky=W)

S3Lb = Label(root, text="Symptom 3", fg="Green",bg="white")
S3Lb.config(font=("Times",15,"bold italic"))
S3Lb.grid(row=9, column=0, pady=10,padx=20, sticky=W)

S4Lb = Label(root, text="Symptom 4", fg="blue", bg="Yellow")
S4Lb.config(font=("Times",15,"bold italic"))
S4Lb.grid(row=10, column=0, pady=10,padx=20, sticky=W)

S5Lb = Label(root, text="Symptom 5", fg="purple", bg="light green")
S5Lb.config(font=("Times",15,"bold italic"))
S5Lb.grid(row=11, column=0, pady=10,padx=20, sticky=W)


dstLb = Label(root, text="DecisionTree", fg="white", bg="red")
dstLb.config(font=("Times",15,"bold italic"))
dstLb.grid(row=15, column=0, pady=10,padx=20,sticky=W)

rnfLb = Label(root, text="RandomForest", fg="Red", bg="Orange")
rnfLb.config(font=("Times",15,"bold italic"))
rnfLb.grid(row=17, column=0, pady=10,padx=20, sticky=W)

nbLb = Label(root, text="NaiveBayes", fg="yellow", bg="brown")
nbLb.config(font=("Times",15,"bold italic"))
nbLb.grid(row=19, column=0, pady=10,padx=20, sticky=W)

OPTIONS = sorted(l1)   #list l1 which contains symptoms is sorted alphabetically for the user to choose from

NameEn = Entry(root, textvariable=Name)  #entry function is used to accept the name of the user as input in the form of string & root here represent the parent window
NameEn.grid(row=6, column=1)

S1 = OptionMenu(root, Symptom1,*OPTIONS)  #dropdown would be displayed for all the symptoms for the users to choose from(for symptom 1, 2 ,3, 4 & 5)
S1.grid(row=7, column=1)

S2 = OptionMenu(root, Symptom2,*OPTIONS)
S2.grid(row=8, column=1)

S3 = OptionMenu(root, Symptom3,*OPTIONS)
S3.grid(row=9, column=1)

S4 = OptionMenu(root, Symptom4,*OPTIONS)
S4.grid(row=10, column=1)

S5 = OptionMenu(root, Symptom5,*OPTIONS)
S5.grid(row=11, column=1)


dst = Button(root, text="Prediction 1", command=DecisionTree,bg="Red",fg="yellow")  #button to predict disease using dicision tree algorithm
dst.config(font=("Times",15,"bold italic"))
dst.grid(row=8, column=3,padx=10)

rnf = Button(root, text="Prediction 2", command=randomforest,bg="White",fg="green") #button to predict disease using random forest algorithm
rnf.config(font=("Times",15,"bold italic"))
rnf.grid(row=9, column=3,padx=10)

nb = Button(root, text="Prediction 3", command=NaiveBayes,bg="Blue",fg="white")  #button to predict disease using naive bayes algorithm
nb.config(font=("Times",15,"bold italic"))
nb.grid(row=10, column=3,padx=10)

rs = Button(root,text="Reset", command=Reset,bg="yellow",fg="purple",width=15)  #button to reset all selected symptoms and predicted diseases
rs.config(font=("Times",15,"bold italic"))
rs.grid(row=11,column=3,padx=10)


t1=Label(root,text="Decision Tree",height=1,bg="Light green",width=40,fg="red",textvariable=pred1,relief="sunken")  #box to display disease predicted using decision tree algorithm(here textvariable=pred1 which we already calculated above)
t1.config(font=("Times",15,"bold italic"))
t1.grid(row=15, column=1, padx=10)

t2=Label(root,text="Random Forest",height=1,bg="Purple" ,width=40,fg="white",textvariable=pred2,relief="sunken")  #box to display disease predicted using random forest algorithm(here textvariable=pred2 which we already calculated above)
t2.config(font=("Times",15,"bold italic"))
t2.grid(row=17, column=1, padx=10)

t3=Label(root,text="Naive Bayes",height=1,bg="red",width=40,fg="orange",textvariable=pred3,relief="sunken") #box to display diasease predicted using naive bayes algorithm(here textvariable=pred3 which we already calculated above)
t3.config(font=("Times",15,"bold italic"))
t3.grid(row=19, column=1, padx=10)

note="**NOTES**\n*First two symptoms are mandatary.\n*Select all the symptoms for better accuracy.\n*Click on right side prediction buttons for predicting results. "
noteLb = Label(root, text=note, fg="White", bg="brown")
noteLb.config(font=("Times",15,"bold italic"))
noteLb.grid(row=22, column=1, pady=20 )




root.mainloop()   #used to run our application by opening the window which we created now
# Out:
# DecisionTree Accuracy: 0.9512195121951219
# NaiveBayes Accuracy: 0.9512195121951219
# Randomforest Accuracy: 0.9512195121951219
